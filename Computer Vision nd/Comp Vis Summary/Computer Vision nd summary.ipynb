# %% [markdown]
# # Computer Vision nd summary

# %% [markdown]
# ## Content
# **<center> Parts</center>**  <br>
# - [**Part 1**](#Concept-1) **Introduction to Computer Vision** ------------------------------------------------$\downarrow$
# - [**Part 2**](#Concept-2) **Advanced Computer Vision & Deep Learning**  $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$  | -------$\rightarrow$ the important parts
# - [**Part 3**](#Concept-3) **Object Tracking and Localization** -----------------------------------------------$\uparrow$ <br>
# (i will finish the upper two, then do my capstone project, then do the third part here, then apply to nile (or i may finish the three parts then apply to nile then do the capstone project, it all depends on how much left is available to me before the deadlins) )
# ---
# ---
# ---
# - [**Part 4**](#Concept-3) (Elective) **Applications of Computer Vision and Deep Learning**<br>
# - [**Part 5**](#Concept-4) (Elective) **Review: Training A Neural Network**<br>
# - [**Part 6**](#Concept-5) (Elective) **Skin Cancer Detection**<br>
# - [**Part 7**](#Concept-6) (Elective) **Text Sentiment Analysis**<br>
# - [**Part 8**](#Concept-7) (Elective) **More Deep Learning Models**<br>
# - [**Part 9**](#Concept-8) (Elective) **C++ Programming**<br>
#
# **<center> Parts and Lessons</center>**  <br>
#
# - [**Part 1**](#Concept-1) **Introduction to Computer Vision**<br>
#     - Lesson 1 --> Welcome to Computer Vision.
#     - Lesson 2 --> Image Representation & Classification
#     - Lesson 3 --> Convolutional Filters and Edge Detection
#     - Lesson 4 --> Types of Features & Image Segmentation
#     - Lesson 5 --> Feature Vectors
#     - Lesson 6 --> CNN Layers and Feature Visualization
#     - Lesson 7 --> Project: Facial Keypoint Detection
# - [**Part 2**](#Concept-2) **Advanced Computer Vision & Deep Learning**<br>
#     - Lesson 1 --> Advanced CNN Architectures
#     - Lesson 2 --> YOLO
#     - Lesson 3 --> RNN's
#     - Lesson 4 --> Long Short-Term Memory Networks (LSTMs)
#     - Lesson 5 --> Hyperparameters
#     - Lesson 6 --> Optional: Attention Mechanisms
#     - Lesson 7 --> Image Captioning
#     - Lesson 8 --> Project: Image Captioning
#     - Lesson 9 --> Optional: Cloud Computing with AWS
# - [**Part 3**](#Concept-3) **Object Tracking and Localization**<br>
#     - Lesson 1 --> Introduction to Motion
#     - Lesson 2 --> Robot Localization
#     - Lesson 3 --> Mini-project: 2D Histogram Filter
#     - Lesson 4 --> Introduction to Kalman Filters
#     - Lesson 5 --> Representing State and Motion
#     - Lesson 6 --> Matrices and Transformation of State
#     - Lesson 7 --> Simultaneous Localization and Mapping
#     - Lesson 8 --> Optional: Vehicle Motion and Calculus
#     - Lesson 9 --> Project: Landmark Detection & Tracking (SLAM)
# ---
# ---
# ---
# - [**Part 4**](#Concept-3) (Elective) **Applications of Computer Vision and Deep Learning**<br>
#     - Lesson 1 --> Applying Deep Learning Models
# - [**Part 5**](#Concept-4) (Elective) **Review: Training A Neural Network**<br>
#     - Lesson 1 --> Feedforward and Backpropagation
#     - Lesson 2 --> Training Neural Networks
#     - Lesson 3 --> Deep Learning with PyTorch
# - [**Part 6**](#Concept-5) (Elective) **Skin Cancer Detection**<br>
#     - Lesson 1 --> Deep Learning for Cancer Detection with Sebastian Thrun
# - [**Part 7**](#Concept-6) (Elective) **Text Sentiment Analysis**<br>
#     - Lesson 1 --> Sentiment Analysis
# - [**Part 8**](#Concept-7) (Elective) **More Deep Learning Models**<br>
#     - Lesson 1 --> Fully-Convolutional Neural Networks & Semantic Segmentation
# - [**Part 9**](#Concept-8) (Elective) **C++ Programming**<br>
#     - Module 1 -> C++ Basics
#         - Lesson 1 --> C++ Getting Started
#         - Lesson 2 --> C++ Vectors
#         - Lesson 3 --> Practical C++
#         - Lesson 4 --> C++ Object Oriented Programming
#         - Lesson 5 --> Python and C++ Speed
#     - Module 2 -> Performance Programming in C++
#         - Lesson 1 --> C++ Intro to Optimization
#         - Lesson 2 --> C++ Optimization Practice
#         - Lesson 3 --> Project: Optimize Histogram Filter
# ---
# ---
# ---
#
# **<center> Parts and Lessons and Concepts</center>**  <br>
# - [**Part 1**](#Concept-1) **Introduction to Computer Vision**<br>
#     - Lesson 1 --> Welcome to Computer Vision.
#         - Concept 1: Welcome to the Computer Vision Nanodegree Program
#         - Concept 2: Computer Vision in Industry
#         - Concept 3: Course Outline
#         - Concept 4: Projects and Topics
#         - Concept 5: Partnership with Industry
#         - Concept 6: Learning in the Classroom
#         - Concept 7: Deadline Policy
#         - Concept 8: Udacity Support
#         - Concept 9: Community Guidelines
#         - Concept 10: Moving Forward!
#     - lesson 2 --> Image Representation & Classification
#         - Concept 1: Intro to Pattern Recognition
#         - Concept 2: Emotional Intelligence
#         - Concept 3: Computer Vision Pipeline
#         - Concept 4: Training a Model
#         - Concept 5: Separating Data
#         - Concept 6: AffdexMe Demo
#         - Concept 7: Image Formation
#         - Concept 8: Images as Grids of Pixels
#         - Concept 9: Notebook: Images as Numerical Data
#         - Concept 10: Color Images
#         - Concept 11: Color or Grayscale?
#         - Concept 12: Notebook: Visualizing RGB Channels
#         - Concept 13: Color Thresholds
#         - Concept 14: Coding a Blue Screen
#         - Concept 15: Notebook: Blue Screen
#         - Concept 16: Notebook: Green Screen
#         - Concept 17: Color Spaces and Transforms
#         - Concept 18: Notebook: Color Conversion
#         - Concept 19: Day and Night Classification Challenge
#         - Concept 20: Notebook: Load and Visualize the Data
#         - Concept 21: Labeled Data and Accuracy
#         - Concept 22: Distinguishing Traits
#         - Concept 23: Features
#         - Concept 24: Standardizing Output
#         - Concept 25: Notebook: Standardizing Day and Night Images
#         - Concept 26: Average Brightness
#         - Concept 27: Notebook: Average Brightness Feature Extraction
#         - Concept 28: Classification
#         - Concept 29: Notebook: Classification
#         - Concept 30: Evaluation Metrics
#         - Concept 31: Notebook: Accuracy and Misclassification
#         - Concept 32: Review and the Computer Vision Pipeline
#     - lesson 3 --> Convolutional Filters and Edge Detection
#         - Concept 1: Filters and Finding Edges
#         - Concept 2: Frequency in Images
#         - Concept 3: Notebook: Fourier Transforms
#         - Concept 4: Quiz: Fourier Tranform Image
#         - Concept 5: High-pass Filters
#         - Concept 6: Quiz: Kernels
#         - Concept 7: Creating a Filter
#         - Concept 8: Gradients and Sobel Filters
#         - Concept 9: Notebook: Finding Edges
#         - Concept 10: Low-pass Filters
#         - Concept 11: Gaussian Blur
#         - Concept 12: Notebook: Gaussian Blur
#         - Concept 13: Notebook: Fourier Transforms of Filters
#         - Concept 14: Convolutional Layer
#         - Concept 15: Canny Edge Detector
#         - Concept 16: Notebook: Canny Edge Detection
#         - Concept 17: Shape Detection
#         - Concept 18: Hough Transform
#         - Concept 19: Quiz: Hough Space
#         - Concept 20: Hough Line Detection
#         - Concept 21: Notebook: Hough Detections
#         - Concept 22: Object Recognition & Introducing Haar Cascades
#         - Concept 23: Haar Cascades
#         - Concept 24: Notebook: Haar Cascade Face Detection
#         - Concept 25: Face Recognition and the Dangers of Bias
#         - Concept 26: Beyond Edges, Selecting Different Features
#     - lesson 4 --> Types of Features & Image Segmentation
#         - Concept 1: Types of Features
#         - Concept 2: Corner Detectors
#         - Concept 3: Notebook: Find the Corners
#         - Concept 4: Dilation and Erosion
#         - Concept 5: Image Segmentation
#         - Concept 6: Image Contours
#         - Concept 7: Notebook: Find Contours and Features
#         - Concept 8: Solution: Find Contours and Features
#         - Concept 9: K-means Clustering
#         - Concept 10: K-means Implementation
#         - Concept 11: Notebook: K-means Clustering
#     - lesson 5 --> Feature Vectors
#         - Concept 1: Corners and Object Detection
#         - Concept 2: Feature Vectors
#         - Concept 3: Real-Time Feature Detection
#         - Concept 4: Introduction to ORB
#         - Concept 5: FAST
#         - Concept 6: Quiz: FAST Keypoints
#         - Concept 7: BRIEF
#         - Concept 8: Scale and Rotation Invariance
#         - Concept 9: Notebook: Image Pyramids
#         - Concept 10: Feature Matching
#         - Concept 11: ORB in Video
#         - Concept 12: Notebook: Implementing ORB
#         - Concept 13: HOG
#         - Concept 14: Notebook: Implementing HOG
#         - Concept 15: Learning to Find Features
#     - lesson 6 --> CNN Layers and Feature Visualization
#         - Concept 1: Introduction to CNN Layers
#         - Concept 2: Review: Training a Neural Network
#         - Concept 3: Lesson Outline and Data
#         - Concept 4: CNN Architecture, VGG-16
#         - Concept 5: Convolutional Layers
#         - Concept 6: Defining Layers in PyTorch
#         - Concept : Notebook: Visualizing a Convolutional Layer
#         - Concept 8: Pooling, VGG-16 Architecture
#         - Concept 9: Pooling Layers
#         - Concept 10: Notebook: Visualizing a Pooling Layer
#         - Concept 11: Fully-Connected Layers, VGG-16
#         - Concept 12: Notebook: Visualizing FashionMNIST
#         - Concept 13: Training in PyTorch
#         - Concept 14: Notebook: Fashion MNIST Training Exercise
#         - Concept 15: Notebook: FashionMNIST, Solution 1
#         - Concept 16: Review: Dropout
#         - Concept 17: Notebook: FashionMNIST, Solution 2
#         - Concept 18: Network Structure
#         - Concept 19: Feature Visualization
#         - Concept 20: Feature Maps
#         - Concept 21: First Convolutional Layer
#         - Concept 22: Visualizing CNNs (Part 2)
#         - Concept 23: Visualizing Activations
#         - Concept 24: Notebook: Feature Viz for FashionMNIST
#         - Concept 25: Notebook: Visualize Your Net Layers
#         - Concept 26: Last Feature Vector and t-SNE
#         - Concept 27: Occlusion, Saliency, and Guided Backpropagation
#         - Concept 28: Summary of Feature Viz
#         - Concept 29: Image Classification & Regression Challenges
#     - lesson 7 --> Project: Facial Keypoint Detection
#         - Concept 1: Project Overview
#         - Concept 2: Workspaces: Best Practices
#         - Concept 3: Project: Facial Keypoint Detection  <br><br>
#
# - [**Part 2**](#Concept-2) **Advanced Computer Vision & Deep Learning**<br>
