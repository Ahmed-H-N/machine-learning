# %% [markdown]
# # Capstone - Facial Keypoints Detection (CNN model)

# %% [markdown]
# First of all let's discuss what we are given.<br>
# We are given three CSV files.<br>
# training.csv :- Its has coordinates of facial keypoints like left eye, rigth eye etc and also the image.<br>
# test.csv :- Its has image only and we have to give coordinates of various facial keypoints by looking at third csv file which is <br>
# IdLookupTable.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import clear_output
from time import sleep
import os

# %%
os.listdir('.')
# Out:
# ['Capstone - Facial Keypoints Detection (CNN model)-Copy1.ipynb',
#  'training',
#  'Capstone - Facial Keypoints Detection (CNN model).ipynb',
#  '.ipynb_checkpoints',
#  'dog-project.zip',
#  'dog-project']

# %%
Train_Dir = './training/training.csv'
train_data_frame = pd.read_csv(Train_Dir)

# %% [markdown]
# Lets explore our dataset

# %%
train_data_frame.head()
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          66.033564          39.002274           30.227008
# 1          64.332936          34.970077           29.949277
# 2          65.057053          34.909642           30.903789
# 3          65.225739          37.261774           32.023096
# 4          66.725301          39.621261           32.244810
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.421678                59.582075                39.647423
# 1           33.448715                58.856170                35.274349
# 2           34.909642                59.412000                36.320968
# 3           37.261774                60.003339                39.127179
# 4           38.042032                58.565890                39.621261
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                73.130346                39.969997                 36.356571
# 1                70.722723                36.187166                 36.034723
# 2                70.984421                36.320968                 37.678105
# 3                72.314713                38.380967                 37.618643
# 4                72.515926                39.884466                 36.982380
#
#    right_eye_inner_corner_y  \
# 0                 37.389402
# 1                 34.361532
# 2                 36.320968
# 3                 38.754115
# 4                 39.094852
#
#                          ...                          nose_tip_y  \
# 0                        ...                           57.066803
# 1                        ...                           55.660936
# 2                        ...                           53.538947
# 3                        ...                           54.166539
# 4                        ...                           64.889521
#
#    mouth_left_corner_x  mouth_left_corner_y  mouth_right_corner_x  \
# 0            61.195308            79.970165             28.614496
# 1            56.421447            76.352000             35.122383
# 2            60.822947            73.014316             33.726316
# 3            65.598887            72.703722             37.245496
# 4            60.671411            77.523239             31.191755
#
#    mouth_right_corner_y  mouth_center_top_lip_x  mouth_center_top_lip_y  \
# 0             77.388992               43.312602               72.935459
# 1             76.047660               46.684596               70.266553
# 2             72.732000               47.274947               70.191789
# 3             74.195478               50.303165               70.091687
# 4             76.997301               44.962748               73.707387
#
#    mouth_center_bottom_lip_x  mouth_center_bottom_lip_y  \
# 0                  43.130707                  84.485774
# 1                  45.467915                  85.480170
# 2                  47.274947                  78.659368
# 3                  51.561183                  78.268383
# 4                  44.227141                  86.871166
#
#                                                Image
# 0  238 236 237 238 240 240 239 241 241 243 240 23...
# 1  219 215 204 196 204 211 212 200 180 168 178 19...
# 2  144 142 159 180 188 188 184 180 167 132 84 59 ...
# 3  193 192 193 194 194 194 193 192 168 111 50 12 ...
# 4  147 148 160 196 215 214 216 217 219 220 206 18...
#
# [5 rows x 31 columns]

# %% [markdown]
# Lets check for missing values

# %%
# dF.isnull() Returns the same DF but with True whenever NAN(or empty string or numpy.inf) exist, and Flase elsewhere

# dF.any() Return whether any element is True, potentially over an axis. (default axis is the row, i.e the index axis)
       #### what i see is that it did that for each column then transposed the dF into a series !!
       #### here it returns a series (the single column dataFrame in Pandas)

# Series.value_counts Return a Series containing counts of unique values.

train_data_frame.isnull().any(axis=0).value_counts()
# Out:
# True     28
# False     3
# dtype: int64

# %%
# see number of rows that have NAN values
train_data_frame.isnull().any(axis=1).value_counts()
# Out:
# True     4909
# False    2140
# dtype: int64

# %% [markdown]
# - So there are missing values in 28 columns. We can do one of two things here:
#     - one : remove the rows having missing values
#     - two : ill missing values with some data.
#
# using option one will reduce our dataset drastically (more than half of the rows have NAN values!!), so i uesd option two
# I filled the missing values with the previous values in that row.

# %%
train_data_frame.fillna(method = 'ffill',inplace = True)

# %% [markdown]
# Lets check for missing values now

# %%
train_data_frame.isnull().any().value_counts()
# Out:
# False    31
# dtype: int64

# %% [markdown]
# - now, there are no missing values.
# - we can now separate features and target(labels).
#     - The image is our feature and the other values are labels that we have to predict later.
#
# - since image column values are in string format and there are also some missing values (pixels !) so we have to split the pixels' string by space and append it to an list (to be able to display it) and also handling missing values(missing pixels)
#     - we will put "0" in place of the missing pixel

# %%
images_lists = list()
num_of_images = 7049

for i in range(num_of_images): # for each string that corresponds to an iamge
    img_temp_list = train_data_frame['Image'][i].split(' ') # convert the long string into small strings (individual pixels)
    img_temp_list = ['0' if x == '' else x for x in img_temp_list] # handle pixel if is missing -> make it zero
    images_lists.append(img_temp_list)

# %% [markdown]
# - notes
#     - `train_data_frame['Image'][0]` is a string, corresponds to the first image
#     - `string.split(' ')` returns a list of strings, the strings are made from spliting the original long `string` when incountering a ' '

# %% [markdown]
# Lets reshape the image (whiile in the same time make it an array) and convert the image list from being as pixels strings into pixels as float value.

# %%
images_array = np.array(images_lists,dtype = 'float')

# %%
X_train = images_array.reshape(-1,96,96)  # of shape 7094*96*96

# %% [markdown]
# - note:
#     - `image_array` is a numpy array of the size of `7049 x 9216` = `n_images x n_pixels_in_each_image`
#         - i.e each row corresponds to an image
#     - `X_train` is of shape `7049 x 96 x 96`
#         - note that putting the first dimension as -1 in the reshape function means that the first dimension is inferred from the calling ndarray, `images_array`.

# %% [markdown]
# Lets see what is the first image.

# %%
# method 1 in plotting : 
# showing single image
##plt.imshow(X_train[0],cmap='gray')
##plt.show()

# method 2 in plotting : 
# showing several images
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(16,16))

for i in range (5):
    axes[i].imshow(X_train[i],cmap='gray')

# %% [markdown]
# ### here i want to plot the images with its markers

# %% [markdown]
# #### separating labels.

# %%
training = train_data_frame.drop('Image',axis = 1)

y_train = []
for i in range(0,7049):
    y = training.iloc[i,:]

    y_train.append(y)
y_train = np.array(y_train,dtype = 'float')

# %%
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(16,10))

for i in range(3):
    for j in range(5):
        axes[i][j].imshow(X_train[5*i+j],cmap='gray')
        axes[i][j].plot(y_train[5*i+j][0::2], y_train[5*i+j][1::2], 'ro')

# %% [markdown]
# ## Training
# As our data is ready for training , lets define our model. I am using keras and simple dense layers.
# For both loss function and evaluation of the result I am using 'MSE' ( mean squared error ).  (my note: I can use a loss function but evaluate the result against another function. (i.e MSE for one, and MAE for the other))

# %% [markdown]
# #### Split train and test data

# %%
print("X_train shape before splitting= ",X_train.shape)
print("y_train shape before splitting= ",y_train.shape)
# Out:
# X_train shape before splitting=  (7049, 96, 96)
# y_train shape before splitting=  (7049, 30)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
print("X_train shape after splitting= ",X_train.shape)
print("y_train shape after splitting= ",y_train.shape)
# Out:
# X_train shape after splitting=  (5639, 96, 96)
# y_train shape after splitting=  (5639, 30)

# %% [markdown]
# #### Train a CNN model
# - CNN Model :

# %%
# prepare the training input by adding to it a forth dimension (required by keras !)
X_train = X_train.reshape(-1,96,96,1)  # of shape 5639*96*96*1

# %% [markdown]
# #### Defining the model

# %%
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from keras.layers import Activation, Convolution2D, MaxPooling2D
from keras.layers import BatchNormalization, Flatten, Dense, Dropout, Conv2D,MaxPool2D, ZeroPadding2D
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# group 1
model.add(Convolution2D(32, (3,3), padding='same', use_bias=False, input_shape=(96,96,1)))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

# group 2
model.add(Convolution2D(32, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# group 3
model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())


# group 4
model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))


# group 5
model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

# group 6
model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# group 7
model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

# group 8
model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# group 9
model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

# group 10
model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# group 11
model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

# group 12
model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())


model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(30))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        288
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 96, 96, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 32)        9216
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 96, 96, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        18432
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 48, 48, 64)        36864
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 96)        55296
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 24, 24, 96)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 24, 96)        384
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 24, 24, 96)        82944
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 24, 24, 96)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 24, 24, 96)        384
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 96)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 128)       110592
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 128)       147456
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 6, 6, 256)         294912
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 6, 6, 256)         589824
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 3, 3, 512)         1179648
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 3, 512)         2359296
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               2359808
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 7,268,670
# Trainable params: 7,264,318
# Non-trainable params: 4,352
# _________________________________________________________________

# %%
model.compile(optimizer='adam', 
              loss='mean_squared_error',
              metrics=['mse'])

# %% [markdown]
# Now our model is defined and we will train it by calling fit method. I ran it for 500 iteration (how?!) keeping batch size and validtion set size as 20% ( 20% of the training data will be kept for validating the model ).

# %%
history = model.fit(X_train,y_train,epochs = 50,batch_size = 256, validation_split = 0.2)
# Out:
# Train on 4511 samples, validate on 1128 samples
# Epoch 1/50
# 4511/4511 [==============================] - 35s 8ms/step - loss: 519.9583 - mean_squared_error: 519.9583 - val_loss: 622.2958 - val_mean_squared_error: 622.2958
# Epoch 2/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 80.7792 - mean_squared_error: 80.7792 - val_loss: 78.4368 - val_mean_squared_error: 78.4368
# Epoch 3/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 59.9839 - mean_squared_error: 59.9839 - val_loss: 32.2773 - val_mean_squared_error: 32.2773
# Epoch 4/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 50.6829 - mean_squared_error: 50.6829 - val_loss: 34.6979 - val_mean_squared_error: 34.6979
# Epoch 5/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 44.8837 - mean_squared_error: 44.8837 - val_loss: 40.4656 - val_mean_squared_error: 40.4656
# Epoch 6/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 40.2659 - mean_squared_error: 40.2659 - val_loss: 34.0566 - val_mean_squared_error: 34.0566
# Epoch 7/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 36.8173 - mean_squared_error: 36.8173 - val_loss: 32.9223 - val_mean_squared_error: 32.9223
# Epoch 8/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 34.0907 - mean_squared_error: 34.0907 - val_loss: 29.4028 - val_mean_squared_error: 29.4028
# Epoch 9/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 31.8471 - mean_squared_error: 31.8471 - val_loss: 28.4729 - val_mean_squared_error: 28.4729
# Epoch 10/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 29.5836 - mean_squared_error: 29.5836 - val_loss: 17.5709 - val_mean_squared_error: 17.5709
# Epoch 11/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 27.9781 - mean_squared_error: 27.9781 - val_loss: 26.3876 - val_mean_squared_error: 26.3876
# Epoch 12/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 26.4108 - mean_squared_error: 26.4108 - val_loss: 34.3766 - val_mean_squared_error: 34.3766
# Epoch 13/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 27.7987 - mean_squared_error: 27.7987 - val_loss: 35.8174 - val_mean_squared_error: 35.8174
# Epoch 14/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 26.8834 - mean_squared_error: 26.8834 - val_loss: 5.9827 - val_mean_squared_error: 5.9827
# Epoch 15/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 24.9632 - mean_squared_error: 24.9632 - val_loss: 5.8107 - val_mean_squared_error: 5.8107
# Epoch 16/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 23.4437 - mean_squared_error: 23.4437 - val_loss: 9.0882 - val_mean_squared_error: 9.0882
# Epoch 17/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 21.9203 - mean_squared_error: 21.9203 - val_loss: 15.6549 - val_mean_squared_error: 15.6549
# Epoch 18/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 21.6670 - mean_squared_error: 21.6670 - val_loss: 8.3444 - val_mean_squared_error: 8.3444
# Epoch 19/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 23.0274 - mean_squared_error: 23.0274 - val_loss: 9.5401 - val_mean_squared_error: 9.5401
# Epoch 20/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 21.0568 - mean_squared_error: 21.0568 - val_loss: 5.1736 - val_mean_squared_error: 5.1736
# Epoch 21/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 20.4888 - mean_squared_error: 20.4888 - val_loss: 6.8154 - val_mean_squared_error: 6.8154
# Epoch 22/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 19.4834 - mean_squared_error: 19.4834 - val_loss: 5.9356 - val_mean_squared_error: 5.9356
# Epoch 23/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 18.1687 - mean_squared_error: 18.1687 - val_loss: 6.1959 - val_mean_squared_error: 6.1959
# Epoch 24/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 19.5904 - mean_squared_error: 19.5904 - val_loss: 5.1790 - val_mean_squared_error: 5.1790
# Epoch 25/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 19.4389 - mean_squared_error: 19.4389 - val_loss: 7.1629 - val_mean_squared_error: 7.1629
# Epoch 26/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 17.8710 - mean_squared_error: 17.8710 - val_loss: 5.1913 - val_mean_squared_error: 5.1913
# Epoch 27/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 16.7992 - mean_squared_error: 16.7992 - val_loss: 8.3999 - val_mean_squared_error: 8.3999
# Epoch 28/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 16.8298 - mean_squared_error: 16.8298 - val_loss: 6.5733 - val_mean_squared_error: 6.5733
# Epoch 29/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 16.6377 - mean_squared_error: 16.6377 - val_loss: 6.7820 - val_mean_squared_error: 6.7820
# Epoch 30/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 17.6247 - mean_squared_error: 17.6247 - val_loss: 13.0466 - val_mean_squared_error: 13.0466
# Epoch 31/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 18.2062 - mean_squared_error: 18.2062 - val_loss: 6.2309 - val_mean_squared_error: 6.2309
# Epoch 32/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 15.9591 - mean_squared_error: 15.9591 - val_loss: 4.9738 - val_mean_squared_error: 4.9738
# Epoch 33/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 15.6438 - mean_squared_error: 15.6438 - val_loss: 4.8250 - val_mean_squared_error: 4.8250
# Epoch 34/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 16.5056 - mean_squared_error: 16.5056 - val_loss: 4.8088 - val_mean_squared_error: 4.8088
# Epoch 35/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 14.5442 - mean_squared_error: 14.5442 - val_loss: 4.4602 - val_mean_squared_error: 4.4602
# Epoch 36/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 15.5640 - mean_squared_error: 15.5640 - val_loss: 4.4699 - val_mean_squared_error: 4.4699
# Epoch 37/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 14.3098 - mean_squared_error: 14.3098 - val_loss: 7.7925 - val_mean_squared_error: 7.7925
# Epoch 38/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 15.5384 - mean_squared_error: 15.5384 - val_loss: 5.6777 - val_mean_squared_error: 5.6777
# Epoch 39/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 14.8476 - mean_squared_error: 14.8476 - val_loss: 4.4890 - val_mean_squared_error: 4.4890
# Epoch 40/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 14.4423 - mean_squared_error: 14.4423 - val_loss: 7.9689 - val_mean_squared_error: 7.9689
# Epoch 41/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 14.9972 - mean_squared_error: 14.9972 - val_loss: 8.6541 - val_mean_squared_error: 8.6541
# Epoch 42/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 15.4504 - mean_squared_error: 15.4504 - val_loss: 4.8752 - val_mean_squared_error: 4.8752
# Epoch 43/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 14.0413 - mean_squared_error: 14.0413 - val_loss: 5.5187 - val_mean_squared_error: 5.5187
# Epoch 44/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 13.0316 - mean_squared_error: 13.0316 - val_loss: 11.7112 - val_mean_squared_error: 11.7112
# Epoch 45/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 14.6668 - mean_squared_error: 14.6668 - val_loss: 5.4429 - val_mean_squared_error: 5.4429
# Epoch 46/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 15.5206 - mean_squared_error: 15.5206 - val_loss: 6.2082 - val_mean_squared_error: 6.2082
# Epoch 47/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 17.4841 - mean_squared_error: 17.4841 - val_loss: 14.6571 - val_mean_squared_error: 14.6571
# Epoch 48/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 14.0203 - mean_squared_error: 14.0203 - val_loss: 4.2171 - val_mean_squared_error: 4.2171
# Epoch 49/50
# 4511/4511 [==============================] - 21s 5ms/step - loss: 14.2820 - mean_squared_error: 14.2820 - val_loss: 9.4415 - val_mean_squared_error: 9.4415
# Epoch 50/50
# 4511/4511 [==============================] - 22s 5ms/step - loss: 14.2293 - mean_squared_error: 14.2293 - val_loss: 5.0341 - val_mean_squared_error: 5.0341

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_mean_squared_error', 'loss', 'mean_squared_error'])

# %%
# Plot validation loss
plt.plot(history.history['val_loss'])
plt.title('Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Model Validation Loss',], loc='upper left')
plt.show()

# Plot validation mean squared error
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation MSE')
plt.ylabel('validation mean squared error')
plt.xlabel('epoch')
plt.legend(['Model validation MSE'], loc='upper left')
plt.show()

# Plot loss
plt.plot(history.history['loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Model Loss'], loc='upper left')
plt.show()

# Plot 'mean_absolute_error
plt.plot(history.history['mean_squared_error'])
plt.title('mean_squared_error')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['Model MSE'], loc='upper left')
plt.show()

# %% [markdown]
# #### validation result

# %%
print("MSE before training = {0:.2f}" .format(history.history['mean_squared_error'][0]))
print("MSE after training = {0:.2f}" .format(history.history['mean_squared_error'][len(history.history['mean_squared_error']) -1]))
# Out:
# MSE before training = 519.96
# MSE after training = 14.23

# %% [markdown]
# - validation results in the benchmark model
#     - MSE before training = 696.80
#     - MSE after training = 27.85
#
# - Our model results :
#     - 4 groups of conv layers
#         - MSE =  2.63
#     - 8 groups of conv layers
#         - MSE = 2.85
#     - 12 groups of conv layers
#         - MSE = 1.19
#     - adding dropout 0.1 layer
#         - MSE = 5.78
#     - adding dropout 0.3 layer
#         - MSE = 14.23<br><br>

# %% [markdown]
# #### Testing

# %%
# prepare the testing data by adding to it a forth dimension (required by keras !)
X_test = X_test.reshape(-1,96,96,1)  # of shape 1410*96*96*1

# %%
pred = model.predict(X_test)

# %% [markdown]
# #### testing results

# %%
from sklearn.metrics import mean_squared_error
mse_test = mean_squared_error(y_test,pred)

print("MSE in testing matrix = {0:.2f}" .format(mse_test))
# Out:
# MSE in testing matrix = 5.59

# %% [markdown]
# - testing results in the benchmark model
#     - MSE in testing matrix = 18.31
#
# - Our model results :
#     - 4 groups of conv layers
#         - MSE =  6.57
#     - 8 groups of conv layers
#         - MSE = 15.04
#     - 12 groups of conv layers
#         - MSE = 4.34
#     - adding dropout 0.1 layer
#         - MSE = 4.47
#     - adding dropout 0.3 layer
#         - MSE = 5.59<br><br>

# %% [markdown]
# #### visualize the pictures after using the model prediction

# %%
# should i mul x_train by 255 ? Apparantly no

# return size of the test matrices to the original size
X_test = X_test.reshape(1410, 96, 96)

# %%
# plot
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(16,10))

for i in range(3):
    for j in range(5):
        axes[i][j].imshow(X_test[5*i+j],cmap='gray')
        axes[i][j].plot(pred[5*i+j][0::2], pred[5*i+j][1::2], 'ro')
